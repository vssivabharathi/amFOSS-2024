# %%
import os
import re
import cv2 as cv
import numpy as np
from PIL import Image, ImageDraw

# %%
def sort_images(image_folder):
    images = os.listdir(image_folder)
    images.sort(key=lambda x: int(re.search(r'\d+', x).group()))
    return images

def detect_dot_and_get_properties(image_path):
    # Load the image
    image = cv.imread(image_path)

    # Convert the image to grayscale
    gray_image = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

    # Apply a binary threshold to the grayscale image
    _, thresholded_image = cv.threshold(gray_image, 200, 255, cv.THRESH_BINARY_INV)

    # Find contours in the thresholded image
    contours, _ = cv.findContours(thresholded_image, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)

    if not contours:
        return None, None, None  # No dot found, equivalent to 'w' command
    
    # Get the first contour's bounding box coordinates (assuming only one dot)
    contour = contours[0]
    x, y, w, h = cv.boundingRect(contour)
    
    # Calculate the center of the dot
    center_x = x + w // 2
    center_y = y + h // 2
    
    # Create a mask for the contour
    mask = np.zeros(image.shape[:2], dtype=np.uint8)
    cv.drawContours(mask, [contour], -1, color=255, thickness=-1)
    
    # Calculate the average color within the contour
    mean_val = cv.mean(image, mask=mask)[:3]
    mean_color = tuple(map(int, mean_val))  # Convert the mean color to integer values
    
    return (center_x, center_y), mean_color, image_path

# %%
def main():
    image_folder = '/home/sivabharathi/Documents/amFOSS/amFOSS-2024/task-10/assets/'  
    images = sort_images(image_folder)

    # Create a white background image to draw lines on
    final_image = Image.new('RGB', (512, 512), color='white')
    draw = ImageDraw.Draw(final_image)

    last_coords = None
    last_color = None

    for image_name in images:
        image_path = os.path.join(image_folder, image_name)

        # Detect dot and get properties
        coords, color, img_name = detect_dot_and_get_properties(image_path)

        if coords is None:
            # If no dot detected, skip drawing
            last_coords = None
            last_color = None
            print(f"{image_name}: No dot detected, skipping")
            continue

        print(f"Dot found in {image_name} at (X: {coords[0]}, Y: {coords[1]}), Color (BGR): {color}")

        if last_coords is None:
            last_coords = coords
            last_color = color
        else:
            # Draw the line from the last detected dot to the current one
            draw.line([last_coords, coords], fill=last_color, width=2)
            last_coords = coords
            last_color = color

    # Save the final image with the drawn lines
    output_path = "output_image.png"
    final_image.save(output_path)
    print(f"Final output image saved as {output_path}")

if __name__ == "__main__":
    main()
# Out:
# Dot found in Layer 1.png at (X: 170, Y: 237), Color (BGR): (0, 0, 0)
# Dot found in Layer 2.png at (X: 160, Y: 226), Color (BGR): (0, 0, 0)
# Dot found in Layer 3.png at (X: 153, Y: 216), Color (BGR): (0, 0, 0)
# Dot found in Layer 4.png at (X: 147, Y: 206), Color (BGR): (0, 0, 0)
# Dot found in Layer 5.png at (X: 142, Y: 195), Color (BGR): (0, 0, 0)
# Dot found in Layer 6.png at (X: 139, Y: 184), Color (BGR): (0, 0, 0)
# Dot found in Layer 7.png at (X: 137, Y: 171), Color (BGR): (0, 0, 0)
# Dot found in Layer 8.png at (X: 136, Y: 160), Color (BGR): (0, 0, 0)
# Dot found in Layer 9.png at (X: 135, Y: 145), Color (BGR): (0, 0, 0)
# Dot found in Layer 10.png at (X: 137, Y: 133), Color (BGR): (0, 0, 0)
# Dot found in Layer 11.png at (X: 141, Y: 121), Color (BGR): (0, 0, 0)
# Dot found in Layer 12.png at (X: 144, Y: 109), Color (BGR): (0, 0, 0)
# Dot found in Layer 13.png at (X: 150, Y: 96), Color (BGR): (0, 0, 0)
# Dot found in Layer 14.png at (X: 156, Y: 85), Color (BGR): (0, 0, 0)
# Dot found in Layer 15.png at (X: 165, Y: 76), Color (BGR): (0, 0, 0)
# Dot found in Layer 16.png at (X: 172, Y: 68), Color (BGR): (0, 0, 0)
# Dot found in Layer 17.png at (X: 180, Y: 59), Color (BGR): (0, 0, 0)
# Dot found in Layer 18.png at (X: 190, Y: 52), Color (BGR): (0, 0, 0)
# Dot found in Layer 19.png at (X: 200, Y: 47), Color (BGR): (0, 0, 0)
# Dot found in Layer 20.png at (X: 210, Y: 43), Color (BGR): (0, 0, 0)
# Dot found in Layer 21.png at (X: 222, Y: 39), Color (BGR): (0, 0, 0)
# Dot found in Layer 22.png at (X: 233, Y: 35), Color (BGR): (0, 0, 0)
# Dot found in Layer 23.png at (X: 244, Y: 33), Color (BGR): (0, 0, 0)
# Dot found in Layer 24.png at (X: 255, Y: 33), Color (BGR): (0, 0, 0)
# Dot found in Layer 25.png at (X: 265, Y: 33), Color (BGR): (0, 0, 0)
# Dot found in Layer 26.png at (X: 276, Y: 34), Color (BGR): (0, 0, 0)
# Dot found in Layer 27.png at (X: 286, Y: 36), Color (BGR): (0, 0, 0)
# Dot found in Layer 28.png at (X: 296, Y: 38), Color (BGR): (0, 0, 0)
# Dot found in Layer 29.png at (X: 315, Y: 48), Color (BGR): (0, 0, 0)
# Dot found in Layer 30.png at (X: 316, Y: 49), Color (BGR): (73, 73, 73)
# Dot found in Layer 31.png at (X: 322, Y: 53), Color (BGR): (0, 0, 0)
# Dot found in Layer 32.png at (X: 331, Y: 60), Color (BGR): (0, 0, 0)
# Dot found in Layer 33.png at (X: 340, Y: 69), Color (BGR): (0, 0, 0)
# Dot found in Layer 34.png at (X: 348, Y: 77), Color (BGR): (0, 0, 0)
# Dot found in Layer 35.png at (X: 355, Y: 87), Color (BGR): (0, 0, 0)
# Dot found in Layer 36.png at (X: 361, Y: 97), Color (BGR): (0, 0, 0)
# Dot found in Layer 37.png at (X: 367, Y: 108), Color (BGR): (0, 0, 0)
# Dot found in Layer 38.png at (X: 371, Y: 119), Color (BGR): (0, 0, 0)
# Dot found in Layer 39.png at (X: 374, Y: 130), Color (BGR): (0, 0, 0)
# Dot found in Layer 40.png at (X: 375, Y: 141), Color (BGR): (0, 0, 0)
# Dot found in Layer 41.png at (X: 375, Y: 153), Color (BGR): (0, 0, 0)
# Dot found in Layer 42.png at (X: 374, Y: 166), Color (BGR): (0, 0, 0)
# Dot found in Layer 43.png at (X: 372, Y: 180), Color (BGR): (0, 0, 0)
# Dot found in Layer 44.png at (X: 369, Y: 191), Color (BGR): (0, 0, 0)
# Dot found in Layer 45.png at (X: 365, Y: 203), Color (BGR): (0, 0, 0)
# Dot found in Layer 46.png at (X: 359, Y: 213), Color (BGR): (0, 0, 0)
# Dot found in Layer 47.png at (X: 353, Y: 222), Color (BGR): (0, 0, 0)
# Dot found in Layer 48.png at (X: 347, Y: 230), Color (BGR): (0, 0, 0)
# Dot found in Layer 49.png at (X: 342, Y: 237), Color (BGR): (0, 0, 0)
# Layer 50.png: No dot detected, skipping
# Dot found in Layer 51.png at (X: 171, Y: 214), Color (BGR): (7, 193, 255)
# Dot found in Layer 52.png at (X: 224, Y: 176), Color (BGR): (7, 193, 255)
# Dot found in Layer 53.png at (X: 284, Y: 249), Color (BGR): (7, 193, 255)
# Layer 54.png: No dot detected, skipping
# Dot found in Layer 55.png at (X: 223, Y: 176), Color (BGR): (7, 193, 255)
# Dot found in Layer 56.png at (X: 280, Y: 128), Color (BGR): (7, 193, 255)
# Layer 57.png: No dot detected, skipping
# Dot found in Layer 58.png at (X: 277, Y: 130), Color (BGR): (7, 193, 255)
# Dot found in Layer 59.png at (X: 318, Y: 182), Color (BGR): (7, 193, 255)
# Layer 71.png: No dot detected, skipping
# Dot found in Layer 72.png at (X: 194, Y: 285), Color (BGR): (0, 0, 0)
# Dot found in Layer 73.png at (X: 316, Y: 285), Color (BGR): (0, 0, 0)
# Layer 74.png: No dot detected, skipping
# Dot found in Layer 75.png at (X: 193, Y: 320), Color (BGR): (0, 0, 0)
# Dot found in Layer 76.png at (X: 316, Y: 321), Color (BGR): (0, 0, 0)
# Layer 77.png: No dot detected, skipping
# Dot found in Layer 78.png at (X: 215, Y: 349), Color (BGR): (7, 193, 255)
# Dot found in Layer 79.png at (X: 293, Y: 349), Color (BGR): (7, 193, 255)
# Layer 80.png: No dot detected, skipping
# Dot found in Layer 81.png at (X: 285, Y: 350), Color (BGR): (7, 193, 255)
# Dot found in Layer 82.png at (X: 281, Y: 358), Color (BGR): (7, 193, 255)
# Dot found in Layer 83.png at (X: 275, Y: 366), Color (BGR): (7, 193, 255)
# Dot found in Layer 84.png at (X: 269, Y: 372), Color (BGR): (7, 193, 255)
# Dot found in Layer 85.png at (X: 262, Y: 376), Color (BGR): (7, 193, 255)
# Dot found in Layer 86.png at (X: 255, Y: 378), Color (BGR): (7, 193, 255)
# Dot found in Layer 87.png at (X: 245, Y: 376), Color (BGR): (7, 193, 255)
# Dot found in Layer 88.png at (X: 238, Y: 370), Color (BGR): (7, 193, 255)
# Dot found in Layer 89.png at (X: 232, Y: 364), Color (BGR): (7, 193, 255)
# Dot found in Layer 90.png at (X: 227, Y: 357), Color (BGR): (7, 193, 255)
# Dot found in Layer 91.png at (X: 223, Y: 350), Color (BGR): (7, 193, 255)
# Layer 92.png: No dot detected, skipping
# Dot found in Layer 93.png at (X: 232, Y: 357), Color (BGR): (7, 193, 255)
# Dot found in Layer 94.png at (X: 275, Y: 357), Color (BGR): (7, 193, 255)
# Layer 95.png: No dot detected, skipping
# Dot found in Layer 96.png at (X: 242, Y: 366), Color (BGR): (7, 193, 255)
# Dot found in Layer 97.png at (X: 266, Y: 366), Color (BGR): (7, 193, 255)
# Final output image saved as output_image.png
